# %%
import requests
import pandas as pd

import json
 

try:
    url = "https://api.stackexchange.com/2.2/search?order=desc&sort=activity&intitle=perl&site=stackoverflow"
    r = requests.get(url)
    print("JSON:\n", r.text)
    print(type(r.text))
    
except:
    print("Invalid URL or some error occured while making the GET request to the specified URL")
# Out:
# JSON:
#  {"items":[{"tags":["regex","perl"],"owner":{"reputation":5095,"user_id":8710344,"user_type":"registered","accept_rate":80,"profile_image":"https://www.gravatar.com/avatar/e2292c452c0d0c9824d2aa38bb74d9fc?s=256&d=identicon&r=PG&f=1","display_name":"HardcoreHenry","link":"https://stackoverflow.com/users/8710344/hardcorehenry"},"is_answered":true,"view_count":58,"answer_count":2,"score":1,"last_activity_date":1660682662,"creation_date":1660663813,"last_edit_date":1660663908,"question_id":73376526,"content_license":"CC BY-SA 4.0","link":"https://stackoverflow.com/questions/73376526/perl-regex-for-matching-multiline-calls-to-c-function","title":"perl regex for matching multiline calls to c function"},{"tags":["perl","formatting","report"],"owner":{"reputation":2696,"user_id":6124824,"user_type":"registered","profile_image":"https://www.gravatar.com/avatar/dc81b6fda21a94d3f337e2e28463295e?s=256&d=identicon&r=PG","display_name":"vkk05","link":"https://stackoverflow.com/users/6124824/vkk05"},"is_answered":true,"view_count":92,"accepted_answer_id":73173139,"answer_count":1,"score":1,"last_activity_date":1660676235,"creation_date":1659089796,"last_edit_date":1659768266,"question_id":73165106,"content_license":"CC BY-SA 4.0","link":"https://stackoverflow.com/questions/73165106/print-size-and-count-in-adjacent-rather-than-in-new-line-in-perl","title":"Print size and count in adjacent rather than in new line in Perl"},{"tags":["regex","perl"],"owner":{"reputation":23,"user_id":19770839,"user_type":"registered","profile_image":"https://www.gravatar.com/avatar/e757a0926de89714caa7fd2c9a4e7222?s=256&d=identicon&r=PG","display_name":"simoneante","link":"https://stackoverflow.com/users/19770839/simoneante"},"is_answered":true,"view_count":40,"accepted_answer_id":73376850,"answer_count":2,"score":2,"last_activity_date":1660674530,"creation_date":1660664991,"last_edit_date":1660665564,"question_id":73376798,"content_license":"CC BY-SA 4.0","link":"https://stackoverflow.com/questions/73376798/perl-regex-with-capture-groups-not-working","title":"Perl regex with capture groups not working"},{"tags":["perl"],"owner":{"reputation":3965,"user_id":10760768,"user_type":"registered","profile_image":"https://www.gravatar.com/avatar/c1655d01be2cdb32d82573fefc465ef5?s=256&d=identicon&r=PG","display_name":"Daniel Hao","link":"https://stackoverflow.com/users/10760768/daniel-hao"},"is_answered":true,"view_count":45,"closed_date":1660665224,"accepted_answer_id":73376046,"answer_count":1,"score":-1,"last_activity_date":1660673970,"creation_date":1660660897,"last_edit_date":1660673970,"question_id":73375876,"link":"https://stackoverflow.com/questions/73375876/perl-idiomatic-way-to-do-grading-of-scores","closed_reason":"Opinion-based","title":"Perl idiomatic way to do grading of scores?"},{"tags":["sorting","perl","hash","cmp","arrayref"],"owner":{"reputation":674,"user_id":2035207,"user_type":"registered","accept_rate":71,"profile_image":"https://www.gravatar.com/avatar/23407540c4b23ef4f9b4ef62677576ae?s=256&d=identicon&r=PG","display_name":"h q","link":"https://stackoverflow.com/users/2035207/h-q"},"is_answered":true,"view_count":22,"closed_date":1660676944,"answer_count":1,"score":0,"last_activity_date":1660672376,"creation_date":1660671059,"question_id":73378028,"link":"https://stackoverflow.com/questions/73378028/perl-sort-hash-ref-using-multiple-array-ref-values","closed_reason":"Not suitable for this site","title":"Perl: sort hash ref using multiple array ref values"},{"tags":["perl","email","ssl","imap","attachment"],"owner":{"reputation":6849,"user_id":146250,"user_type":"registered","accept_rate":97,"profile_image":"https://www.gravatar.com/avatar/b7d1e3d8a7a3e842a722415b29d4041b?s=256&d=identicon&r=PG","display_name":"Space","link":"https://stackoverflow.com/users/146250/space"},"is_answered":true,"view_count":10648,"accepted_answer_id":2458024,"answer_count":4,"score":7,"last_activity_date":1660671367,"creation_date":1268735362,"last_edit_date":1269003 ...
# <class 'str'>

# %%
data = json.loads(r.text)
print(data)

df = pd.DataFrame.from_dict(data) 
df.to_csv('data.csv')
df
# Out:
# {'items': [{'tags': ['regex', 'perl'], 'owner': {'reputation': 5095, 'user_id': 8710344, 'user_type': 'registered', 'accept_rate': 80, 'profile_image': 'https://www.gravatar.com/avatar/e2292c452c0d0c9824d2aa38bb74d9fc?s=256&d=identicon&r=PG&f=1', 'display_name': 'HardcoreHenry', 'link': 'https://stackoverflow.com/users/8710344/hardcorehenry'}, 'is_answered': True, 'view_count': 58, 'answer_count': 2, 'score': 1, 'last_activity_date': 1660682662, 'creation_date': 1660663813, 'last_edit_date': 1660663908, 'question_id': 73376526, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73376526/perl-regex-for-matching-multiline-calls-to-c-function', 'title': 'perl regex for matching multiline calls to c function'}, {'tags': ['perl', 'formatting', 'report'], 'owner': {'reputation': 2696, 'user_id': 6124824, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/dc81b6fda21a94d3f337e2e28463295e?s=256&d=identicon&r=PG', 'display_name': 'vkk05', 'link': 'https://stackoverflow.com/users/6124824/vkk05'}, 'is_answered': True, 'view_count': 92, 'accepted_answer_id': 73173139, 'answer_count': 1, 'score': 1, 'last_activity_date': 1660676235, 'creation_date': 1659089796, 'last_edit_date': 1659768266, 'question_id': 73165106, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73165106/print-size-and-count-in-adjacent-rather-than-in-new-line-in-perl', 'title': 'Print size and count in adjacent rather than in new line in Perl'}, {'tags': ['regex', 'perl'], 'owner': {'reputation': 23, 'user_id': 19770839, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/e757a0926de89714caa7fd2c9a4e7222?s=256&d=identicon&r=PG', 'display_name': 'simoneante', 'link': 'https://stackoverflow.com/users/19770839/simoneante'}, 'is_answered': True, 'view_count': 40, 'accepted_answer_id': 73376850, 'answer_count': 2, 'score': 2, 'last_activity_date': 1660674530, 'creation_date': 1660664991, 'last_edit_date': 1660665564, 'question_id': 73376798, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73376798/perl-regex-with-capture-groups-not-working', 'title': 'Perl regex with capture groups not working'}, {'tags': ['perl'], 'owner': {'reputation': 3965, 'user_id': 10760768, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/c1655d01be2cdb32d82573fefc465ef5?s=256&d=identicon&r=PG', 'display_name': 'Daniel Hao', 'link': 'https://stackoverflow.com/users/10760768/daniel-hao'}, 'is_answered': True, 'view_count': 45, 'closed_date': 1660665224, 'accepted_answer_id': 73376046, 'answer_count': 1, 'score': -1, 'last_activity_date': 1660673970, 'creation_date': 1660660897, 'last_edit_date': 1660673970, 'question_id': 73375876, 'link': 'https://stackoverflow.com/questions/73375876/perl-idiomatic-way-to-do-grading-of-scores', 'closed_reason': 'Opinion-based', 'title': 'Perl idiomatic way to do grading of scores?'}, {'tags': ['sorting', 'perl', 'hash', 'cmp', 'arrayref'], 'owner': {'reputation': 674, 'user_id': 2035207, 'user_type': 'registered', 'accept_rate': 71, 'profile_image': 'https://www.gravatar.com/avatar/23407540c4b23ef4f9b4ef62677576ae?s=256&d=identicon&r=PG', 'display_name': 'h q', 'link': 'https://stackoverflow.com/users/2035207/h-q'}, 'is_answered': True, 'view_count': 22, 'closed_date': 1660676944, 'answer_count': 1, 'score': 0, 'last_activity_date': 1660672376, 'creation_date': 1660671059, 'question_id': 73378028, 'link': 'https://stackoverflow.com/questions/73378028/perl-sort-hash-ref-using-multiple-array-ref-values', 'closed_reason': 'Not suitable for this site', 'title': 'Perl: sort hash ref using multiple array ref values'}, {'tags': ['perl', 'email', 'ssl', 'imap', 'attachment'], 'owner': {'reputation': 6849, 'user_id': 146250, 'user_type': 'registered', 'accept_rate': 97, 'profile_image': 'https://www.gravatar.com/avatar/b7d1e3d8a7a3e842a722415b29d4041b?s=256&d=identicon&r=PG', 'display_name': 'Space', 'link':  ...
#                                                 items  has_more  quota_max  \
# 0   {'tags': ['regex', 'perl'], 'owner': {'reputat...      True        300
# 1   {'tags': ['perl', 'formatting', 'report'], 'ow...      True        300
# 2   {'tags': ['regex', 'perl'], 'owner': {'reputat...      True        300
# 3   {'tags': ['perl'], 'owner': {'reputation': 396...      True        300
# 4   {'tags': ['sorting', 'perl', 'hash', 'cmp', 'a...      True        300
# 5   {'tags': ['perl', 'email', 'ssl', 'imap', 'att...      True        300
# 6   {'tags': ['arrays', 'perl', 'hash'], 'owner': ...      True        300
# 7   {'tags': ['macos', 'perl', 'libpng'], 'owner':...      True        300
# 8   {'tags': ['perl'], 'owner': {'reputation': 11,...      True        300
# 9   {'tags': ['regex', 'perl'], 'owner': {'reputat...      True        300
# 10  {'tags': ['perl', 'subroutine'], 'owner': {'re...      True        300
# 11  {'tags': ['regex', 'linux', 'perl'], 'owner': ...      True        300
# 12  {'tags': ['regex', 'regexp-replace', 're2', 'r...      True        300
# 13  {'tags': ['arrays', 'list', 'scalar', 'perl'],...      True        300
# 14  {'tags': ['perl'], 'owner': {'reputation': 25,...      True        300
# 15  {'tags': ['perl'], 'owner': {'reputation': 122...      True        300
# 16  {'tags': ['perl', 'version'], 'owner': {'reput...      True        300
# 17  {'tags': ['hex', 'ascii'], 'owner': {'reputati...      True        300
# 18  {'tags': ['perl', 'strace'], 'owner': {'reputa...      True        300
# 19  {'tags': ['perl'], 'owner': {'reputation': 11,...      True        300
# 20  {'tags': ['perl'], 'owner': {'reputation': 584...      True        300
# 21  {'tags': ['c++', 'cmake', 'itk'], 'owner': {'r...      True        300
# 22  {'tags': ['perl', 'utf-8'], 'owner': {'reputat...      True        300
# 23  {'tags': ['perl', 'tcsh'], 'owner': {'reputati...      True        300
# 24  {'tags': ['perl'], 'owner': {'reputation': 770...      True        300
# 25  {'tags': ['perl', 'unix', 'ldap'], 'owner': {'...      True        300
# 26  {'tags': ['perl'], 'owner': {'reputation': 1, ...      True        300
# 27  {'tags': ['perl', 'cross-platform'], 'owner': ...      True        300
# 28  {'tags': ['zsh'], 'owner': {'reputation': 164,...      True        300
# 29  {'tags': ['windows', 'perl'], 'owner': {'reput...      True        300
#
#     quota_remaining
# 0               299
# 1               299
# 2               299
# 3               299
# 4               299
# 5               299
# 6               299
# 7               299
# 8               299
# 9               299
# 10              299
# 11              299
# 12              299
# 13              299
# 14              299
# 15              299
# 16              299
# 17              299
# 18              299
# 19              299
# 20              299
# 21              299
# 22              299
# 23              299
# 24              299
# 25              299
# 26              299
# 27              299
# 28              299
# 29              299

# %%
import pandas as pd
 
df = pd.read_csv("data.csv")

#print(df)
df
# Out:
#     Unnamed: 0                                              items  has_more  \
# 0            0  {'tags': ['regex', 'perl'], 'owner': {'reputat...      True
# 1            1  {'tags': ['perl', 'formatting', 'report'], 'ow...      True
# 2            2  {'tags': ['regex', 'perl'], 'owner': {'reputat...      True
# 3            3  {'tags': ['perl'], 'owner': {'reputation': 396...      True
# 4            4  {'tags': ['sorting', 'perl', 'hash', 'cmp', 'a...      True
# 5            5  {'tags': ['perl', 'email', 'ssl', 'imap', 'att...      True
# 6            6  {'tags': ['arrays', 'perl', 'hash'], 'owner': ...      True
# 7            7  {'tags': ['macos', 'perl', 'libpng'], 'owner':...      True
# 8            8  {'tags': ['perl'], 'owner': {'reputation': 11,...      True
# 9            9  {'tags': ['regex', 'perl'], 'owner': {'reputat...      True
# 10          10  {'tags': ['perl', 'subroutine'], 'owner': {'re...      True
# 11          11  {'tags': ['regex', 'linux', 'perl'], 'owner': ...      True
# 12          12  {'tags': ['regex', 'regexp-replace', 're2', 'r...      True
# 13          13  {'tags': ['arrays', 'list', 'scalar', 'perl'],...      True
# 14          14  {'tags': ['perl'], 'owner': {'reputation': 25,...      True
# 15          15  {'tags': ['perl'], 'owner': {'reputation': 122...      True
# 16          16  {'tags': ['perl', 'version'], 'owner': {'reput...      True
# 17          17  {'tags': ['hex', 'ascii'], 'owner': {'reputati...      True
# 18          18  {'tags': ['perl', 'strace'], 'owner': {'reputa...      True
# 19          19  {'tags': ['perl'], 'owner': {'reputation': 11,...      True
# 20          20  {'tags': ['perl'], 'owner': {'reputation': 584...      True
# 21          21  {'tags': ['c++', 'cmake', 'itk'], 'owner': {'r...      True
# 22          22  {'tags': ['perl', 'utf-8'], 'owner': {'reputat...      True
# 23          23  {'tags': ['perl', 'tcsh'], 'owner': {'reputati...      True
# 24          24  {'tags': ['perl'], 'owner': {'reputation': 770...      True
# 25          25  {'tags': ['perl', 'unix', 'ldap'], 'owner': {'...      True
# 26          26  {'tags': ['perl'], 'owner': {'reputation': 1, ...      True
# 27          27  {'tags': ['perl', 'cross-platform'], 'owner': ...      True
# 28          28  {'tags': ['zsh'], 'owner': {'reputation': 164,...      True
# 29          29  {'tags': ['windows', 'perl'], 'owner': {'reput...      True
#
#     quota_max  quota_remaining
# 0         300              299
# 1         300              299
# 2         300              299
# 3         300              299
# 4         300              299
# 5         300              299
# 6         300              299
# 7         300              299
# 8         300              299
# 9         300              299
# 10        300              299
# 11        300              299
# 12        300              299
# 13        300              299
# 14        300              299
# 15        300              299
# 16        300              299
# 17        300              299
# 18        300              299
# 19        300              299
# 20        300              299
# 21        300              299
# 22        300              299
# 23        300              299
# 24        300              299
# 25        300              299
# 26        300              299
# 27        300              299
# 28        300              299
# 29        300              299
